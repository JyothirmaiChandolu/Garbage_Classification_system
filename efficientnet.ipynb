# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_408.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_222.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_200.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_285.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_210.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_243.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_214.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_323.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_320.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_272.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_309.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_343.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_137.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_345.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_295.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_186.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_250.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_223.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_259.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_394.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_150.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_118.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_074.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_195.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_373.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_271.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_048.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_141.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_405.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_216.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_289.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_090.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_108.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_278.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_163.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_364.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_284.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_094.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_356.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_258.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_040.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_034.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_226.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_293.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_192.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_086.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_023.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_055.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_007.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_002.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_257.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_005.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_124.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_237.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_170.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_324.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_187.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_233.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_282.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_292.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_360.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_246.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_113.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_097.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_266.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_269.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_328.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_273.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_152.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_298.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_077.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_296.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_327.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_103.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_333.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_122.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_381.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_173.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_116.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_190.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_212.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_249.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_004.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_104.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_403.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_037.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_158.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_006.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_290.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_231.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_406.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_056.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_220.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_251.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_135.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_326.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_064.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_334.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_136.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_063.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_291.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_181.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_404.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_242.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_096.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_100.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_088.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_038.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_387.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_035.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_399.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_325.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_303.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_132.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_218.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_191.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_066.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_287.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_297.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_371.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_281.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_263.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_344.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_106.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_013.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_248.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_314.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_169.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_198.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_188.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_027.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_402.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_140.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_308.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_075.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_385.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_353.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_305.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_221.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_045.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_329.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_054.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_039.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_340.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_009.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_111.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_336.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_018.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_321.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_306.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_383.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_012.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_162.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_089.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_131.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_264.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_247.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_401.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_389.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_067.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_202.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_239.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_358.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_207.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_183.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_348.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_368.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_085.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_234.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_283.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_203.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_157.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_031.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_189.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_125.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_052.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_254.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_362.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_042.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_204.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_346.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_174.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_099.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_107.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_276.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_193.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_370.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_001.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_230.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_059.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_156.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_350.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_092.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_087.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_267.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_393.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_227.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_071.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_317.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_367.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_127.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_168.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_301.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_160.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_347.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_081.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_351.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_095.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_260.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_026.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_073.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_177.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_041.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_014.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_083.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_219.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_049.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_172.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_036.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_016.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_341.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_300.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_069.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_354.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_008.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_252.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_398.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_185.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_053.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_119.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_213.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_175.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_241.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_240.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_123.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_294.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_020.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_407.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_120.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_082.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_208.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_236.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_180.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_179.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_102.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_357.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_167.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_164.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_392.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_165.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_022.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_374.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_142.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_176.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_105.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_331.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_021.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_322.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_311.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_302.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_032.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_379.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_372.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_275.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_386.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_079.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_046.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_224.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_061.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_062.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_080.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_068.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_093.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_112.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_121.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_361.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_019.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_369.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_145.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_410.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_355.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_255.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_194.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_117.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_043.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_315.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_029.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_349.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_316.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_286.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_025.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_318.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_238.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_201.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_197.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_332.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_151.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_391.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_153.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_270.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_384.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_076.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_382.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_154.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_279.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_178.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_352.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_003.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_211.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_366.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_261.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_017.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_339.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_184.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_144.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_338.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_098.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_312.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_060.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_262.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_072.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_058.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_235.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_376.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_215.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_130.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_182.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_101.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_365.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_155.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_307.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_129.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_134.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_015.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_229.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_396.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_146.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_196.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_274.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_091.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_313.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_277.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_253.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_380.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_161.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_139.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_388.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_028.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_149.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_375.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_148.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_268.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_109.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_110.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_065.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_310.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_206.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_409.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_217.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_084.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_143.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_133.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_057.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_159.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_138.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_051.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_024.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_070.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_047.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_256.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_304.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_244.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_397.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_225.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_395.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_359.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_044.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_199.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_078.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_115.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_010.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_288.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_147.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_228.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_232.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_400.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_378.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_128.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_299.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_363.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_126.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_342.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_205.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_209.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_335.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_114.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_050.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_033.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_390.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_377.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_011.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_337.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_166.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_030.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_280.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_330.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_265.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_171.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_319.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/metal/metal_245.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_438.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_473.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_071.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_399.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_184.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_156.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_346.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_223.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_484.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_437.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_165.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_378.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_141.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_213.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_116.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_083.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_478.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_111.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_129.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_318.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_205.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_040.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_168.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_131.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_107.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_075.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_098.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_087.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_289.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_252.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_404.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_154.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_162.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_308.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_316.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_155.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_369.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_054.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_044.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_294.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_171.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_472.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_010.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_177.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_443.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_224.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_276.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_398.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_110.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_064.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_450.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_117.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_454.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_430.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_004.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_031.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_199.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_321.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_368.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_202.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_159.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_400.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_185.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_466.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_120.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_290.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_247.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_254.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_074.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_050.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_186.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_187.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_066.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_415.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_338.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_448.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_456.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_109.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_124.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_216.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_189.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_037.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_238.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_091.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_017.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_081.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_497.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_312.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_433.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_243.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_068.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_353.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_405.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_361.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_323.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_209.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_268.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_113.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_350.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_317.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_142.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_163.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_499.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_001.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_008.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_419.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_417.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_259.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_342.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_459.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_446.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_370.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_376.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_149.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_263.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_206.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_217.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_389.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_356.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_371.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_304.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_351.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_122.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_293.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_444.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_003.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_449.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_063.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_348.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_218.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_463.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_128.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_476.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_431.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_477.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_222.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_377.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_035.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_314.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_373.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_307.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_428.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_006.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_344.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_140.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_009.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_195.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_278.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_427.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_005.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_458.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_007.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_249.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_292.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_175.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_095.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_133.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_360.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_194.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_372.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_306.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_042.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_090.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_267.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_341.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_432.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_158.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_033.jpg
# ...
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_415.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_338.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_197.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_435.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_331.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_121.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_242.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_176.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_441.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_156.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_191.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_238.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_112.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_257.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_470.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_255.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_382.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_307.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_262.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_124.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_439.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_216.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_145.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_150.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_437.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_283.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_459.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_443.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_321.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_347.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_461.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_363.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_184.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_012.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_142.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_473.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_377.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_422.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_016.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_370.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_069.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_169.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_467.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_448.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_208.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_056.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_155.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_154.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_170.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_474.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_468.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_454.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_115.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_223.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_373.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_116.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_264.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_083.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_241.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_388.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_210.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_126.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_144.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_117.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_413.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_431.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_286.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_189.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_236.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_269.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_201.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_022.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_308.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_143.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_010.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_390.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_215.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_217.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_314.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_425.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_066.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_324.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_359.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_103.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_418.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_131.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_395.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_065.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_397.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_278.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_436.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_316.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_037.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_230.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_128.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_240.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_162.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_095.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_372.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_366.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_222.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_322.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_031.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_379.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_229.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_250.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_320.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_410.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_475.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_035.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_183.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_458.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_194.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_306.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_196.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_352.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_119.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_253.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_398.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_076.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_228.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_335.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_339.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_293.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_219.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_356.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_064.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_392.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_260.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_404.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_403.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_477.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_237.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_105.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_344.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_040.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_369.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_462.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_122.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_107.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_052.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_067.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_206.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_129.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_073.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_313.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_180.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_231.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_101.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_427.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_440.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_071.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_134.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_386.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_375.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_429.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_453.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_295.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_481.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_113.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_326.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_281.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_044.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_096.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_179.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_072.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_401.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_310.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_038.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_080.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_287.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_199.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_292.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_063.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_039.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_374.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_406.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_268.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_209.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_337.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_137.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_110.jpg
# /kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/plastic/plastic_389.jpg

# %%
pip install numpy matplotlib seaborn tensorflow scikit-learn gradio
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.12.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Collecting gradio
#   Downloading gradio-5.34.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.72.0rc1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (22.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.9.0)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.13-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.6.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.10.3 (from gradio)
#   Downloading gradio_client-1.10.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.31.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.10.16)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.11.4)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio) (0.25.1)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (6.0.2)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.12.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.47.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.15.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.34.3-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.3->gradio) (2025.3.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.3->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (1.1.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25->seaborn) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading gradio-5.34.2-py3-none-any.whl (54.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 MB 33.7 MB/s eta 0:00:00:00:0100:01
# Downloading gradio_client-1.10.3-py3-none-any.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 21.5 MB/s eta 0:00:00
# Downloading fastapi-0.115.13-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 kB 6.8 MB/s eta 0:00:00
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.12.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 92.5 MB/s eta 0:00:00:00:0100:01
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.0 MB/s eta 0:00:00
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading uvicorn-0.34.3-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 4.1 MB/s eta 0:00:00
# Downloading ffmpy-0.6.0-py3-none-any.whl (5.5 kB)
# Installing collected packages: uvicorn, tomlkit, semantic-version, ruff, python-multipart, groovy, ffmpy, starlette, safehttpx, gradio-client, fastapi, gradio
# Successfully installed fastapi-0.115.13 ffmpy-0.6.0 gradio-5.34.2 gradio-client-1.10.3 groovy-0.1.2 python-multipart-0.0.20 ruff-0.12.0 safehttpx-0.1.6 semantic-version-2.10.0 starlette-0.46.2 tomlkit-0.13.3 uvicorn-0.34.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np  # Importing NumPy for numerical operations and array manipulations
import matplotlib.pyplot as plt  # Importing Matplotlib for plotting graphs and visualizations
import seaborn as sns  # Importing Seaborn for statistical data visualization, built on top of Matplotlib
import tensorflow as tf  # Importing TensorFlow for building and training machine learning models
from tensorflow import keras  # Importing Keras, a high-level API for TensorFlow, to simplify model building
from tensorflow.keras import Layer  # Importing Layer class for creating custom layers in Keras
from tensorflow.keras.models import Sequential  # Importing Sequential model for building neural networks layer-by-layer
from tensorflow.keras.layers import Rescaling , GlobalAveragePooling2D
from tensorflow.keras import layers, optimizers, callbacks  # Importing various modules for layers, optimizers, and callbacks in Keras
from sklearn.utils.class_weight import compute_class_weight  # Importing function to compute class weights for imbalanced datasets
from tensorflow.keras.applications import EfficientNetV2B2  # Importing EfficientNetV2S model for transfer learning
from sklearn.metrics import confusion_matrix, classification_report  # Importing functions to evaluate model performance
import gradio as gr  # Importing Gradio for creating interactive web interfaces for machine learning models
# Out:
# 2025-06-20 12:44:42.198801: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750423482.386821      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750423482.441347      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_dir="/kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset"
image_size = (124, 124)
batch_size = 32
seed = 42

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="training",
    seed=seed,
    shuffle = True,
    image_size=image_size,
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="validation",
    seed=seed,
    shuffle = True,
    image_size=image_size,
    batch_size=batch_size
)
val_class= val_ds.class_names
# Out:
# Found 2527 files belonging to 6 classes.
# Using 2022 files for training.
# I0000 00:00:1750423509.722913      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 2527 files belonging to 6 classes.
# Using 505 files for validation.

# %%
# Get the total number of batches in the validation dataset
val_batches = tf.data.experimental.cardinality(val_ds)  

# Split the validation dataset into two equal parts:
# First half becomes the test dataset
test_ds = val_ds.take(val_batches // 2)  

# Second half remains as the validation dataset
val_dat = val_ds.skip(val_batches // 2)  

# Optimize test dataset by caching and prefetching to improve performance
test_ds_eval = test_ds.cache().prefetch(tf.data.AUTOTUNE)

# %%
print(train_ds.class_names)
print(val_class)
print(len(train_ds.class_names))
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']
# 6

# %%
def count_distribution(dataset, class_names):
    total = 0
    counts = {name: 0 for name in class_names}
    
    for _, labels in dataset:
        for label in labels.numpy():
            class_name = class_names[label]
            counts[class_name] += 1
            total += 1

    for k in counts:
        counts[k] = round((counts[k] / total) * 100, 2)  # Convert to percentage
    return counts

# %%
class_names = train_ds.class_names

# Get class distributions
train_dist = count_distribution(train_ds, class_names)
val_dist = count_distribution(val_ds, class_names)
test_dist = count_distribution(test_ds, class_names)
overall_dist = {}
for k in class_names:
    overall_dist[k] = round((train_dist[k] + val_dist[k]) / 2, 2)

print(train_dist)
print(val_dist)
print(test_dist)
print(overall_dist)
# Out:
# {'cardboard': 16.52, 'glass': 19.73, 'metal': 15.92, 'paper': 23.29, 'plastic': 19.44, 'trash': 5.09}
# {'cardboard': 13.66, 'glass': 20.2, 'metal': 17.43, 'paper': 24.36, 'plastic': 17.62, 'trash': 6.73}
# {'cardboard': 14.06, 'glass': 17.58, 'metal': 16.8, 'paper': 25.0, 'plastic': 19.14, 'trash': 7.42}
# {'cardboard': 15.09, 'glass': 19.96, 'metal': 16.68, 'paper': 23.82, 'plastic': 18.53, 'trash': 5.91}

# %%
# Count class occurrences and prepare label list
class_counts = {i: 0 for i in range(len(class_names))}
all_labels = []

for images, labels in train_ds:
    for label in labels.numpy():
        class_counts[label] += 1
        all_labels.append(label)

# Compute class weights (index aligned)
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(len(class_names)),
    y=all_labels
)

# Create dictionary mapping class index to weight
class_weights = {i: w for i, w in enumerate(class_weights_array)}

# %%
data_augmentation = Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
])

# %%
base_model = EfficientNetV2B2(include_top=False, input_shape=(124, 124, 3),include_preprocessing=True, weights='imagenet')


#  Freeze early layers (to retain general pretrained features)
base_model.trainable = True
for layer in base_model.layers[:100]:  # You can adjust this number
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b2_notop.h5
# 35839040/35839040 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model = Sequential([
    layers.Input(shape=(124, 124, 3)),
    data_augmentation,
    base_model,
    GlobalAveragePooling2D(),
    layers.Dropout(0.3),
    layers.Dense(6, activation='softmax')  # Change to your number of classes
])

# %%
model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
early = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',            # Metric to monitor (validation loss here)
    patience=3,                   # Number of epochs to wait after last improvement before stopping
    restore_best_weights=True     # After stopping, restore the model weights from the epoch with the best val_loss
)

# %%
epochs = 15  # Number of times the model will go through the entire dataset

# Train the model using the fit function
history = model.fit(
    train_ds,                # Training dataset used to adjust model weights
    validation_data=val_ds,   # Validation dataset to monitor performance on unseen data
    epochs=epochs,           # Number of training cycles, referencing the variable set earlier
    class_weight=class_weights,  # Handles class imbalances by assigning appropriate weights
    batch_size=32,           # Number of samples processed in each training step
    callbacks=[early]        # Implements early stopping to prevent unnecessary training
)
# Out:
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.9831 - loss: 0.0492 - val_accuracy: 0.8931 - val_loss: 0.3039
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.9787 - loss: 0.0657 - val_accuracy: 0.9050 - val_loss: 0.3037
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.9869 - loss: 0.0422 - val_accuracy: 0.9149 - val_loss: 0.2815
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - accuracy: 0.9885 - loss: 0.0393 - val_accuracy: 0.9149 - val_loss: 0.2922
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - accuracy: 0.9907 - loss: 0.0313 - val_accuracy: 0.8990 - val_loss: 0.3074
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.9867 - loss: 0.0456 - val_accuracy: 0.9010 - val_loss: 0.2949

# %%
loss, accuracy = model.evaluate(test_ds_eval)
print(f'Test accuracy is{accuracy:.4f}, Test loss is {loss:.4f}')
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9108 - loss: 0.3177
# Test accuracy is0.9102, Test loss is 0.3020

# %%
class_names = train_ds.class_names  

# Take one batch of images and labels from the test dataset for evaluation
for images, labels in test_ds_eval.take(1):  

    # Generate predictions for the batch of images
    predictions = model.predict(images)  

    # Get the predicted class index for each image
    pred_labels = tf.argmax(predictions, axis=1)  

    # Loop through the first 8 images in the batch
    for i in range(8):  
        plt.imshow(images[i].numpy().astype("uint8"))  # Convert and display image
        plt.title(f"True: {class_names[labels[i]]}, Pred: {class_names[pred_labels[i]]}")  # Show actual and predicted class
        plt.axis("off")  # Hide axes for better visualization
        plt.show()  # Display the image with title
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image as keras_image
import numpy as np
from PIL import Image
import requests
from io import BytesIO

# Function to preprocess and predict a single image
def predict_image(model, img_path, class_names, from_url=False):
    # Load image
    if from_url:
        response = requests.get(img_path)
        img = Image.open(BytesIO(response.content)).convert('RGB')
    else:
        img = Image.open(img_path).convert('RGB')
    
    # Resize and convert to array
    img = img.resize((124, 124))
    img_array = keras_image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Shape (1, 124, 124, 3)
    
    # Make prediction
    predictions = model.predict(img_array)
    predicted_class_index = np.argmax(predictions, axis=1)[0]
    confidence = np.max(predictions)

    predicted_class_name = class_names[predicted_class_index]
    print(f"📷 Predicted class: {predicted_class_name} (Confidence: {confidence*100:.2f}%)")
    return predicted_class_name, confidence

# %%
predict_image(model, "/kaggle/input/trash-type-image-dataset/TrashType_Image_Dataset/glass/glass_001.jpg", class_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 📷 Predicted class: glass (Confidence: 99.72%)
# ('glass', 0.99715483)

# %%
image_url = "https://images.freeimages.com/images/large-previews/2b7/glass-1323152.jpg"
predict_image(model, image_url, class_names, from_url=True)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 📷 Predicted class: glass (Confidence: 90.26%)
# ('glass', 0.9025537)
